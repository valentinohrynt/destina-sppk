# %%
import pandas as pd

nama_file_input = 'tourism_with_id.csv' 

nama_file_output = 'tourism_with_id_without_description_and_coordinate.csv' 

kolom_untuk_dipertahankan = [
    'Place_Id', 
    'Place_Name', 
    'Category', 
    'City', 
    'Price', 
    'Rating', 
    'Time_Minutes'
]

try:
    df = pd.read_csv(nama_file_input)

    df_baru = df[kolom_untuk_dipertahankan]

    df_baru.to_csv(nama_file_output, index=False)

    print(f"File '{nama_file_output}' berhasil dibuat hanya dengan kolom: {', '.join(kolom_untuk_dipertahankan)}")

except FileNotFoundError:
    print(f"Error: File '{nama_file_input}' tidak ditemukan. Pastikan nama file dan lokasinya benar.")
except KeyError as e:
    print(f"Error: Kolom {e} tidak ditemukan di file input. Periksa kembali ejaan nama kolom di 'kolom_untuk_dipertahankan'.")
except Exception as e:
    print(f"Terjadi error: {e}")
# Out:
# File 'tourism_with_id_without_description_and_coordinate.csv' berhasil dibuat hanya dengan kolom: Place_Id, Place_Name, Category, City, Price, Rating, Time_Minutes

# %%
import io
import pandas as pd
import numpy as np

try:
    df = pd.read_csv('tourism_with_id_without_description_and_coordinate.csv')
    print("File 'tourism_with_id_without_description_and_coordinate.csv' berhasil dimuat.")
except FileNotFoundError:
    print("Error: File 'tourism_with_id_without_description_and_coordinate.csv' tidak ditemukan.")
    print("Pastikan file tersebut berada di folder yang sama dengan skrip ini.")
    exit() 

full_data_update = {
    0: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    1: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    2: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    3: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    4: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    5: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    6: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    7: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    8: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    9: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 6},
    10: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 6},
    11: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 5},
    12: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 5},
    13: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 6},
    14: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    15: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    16: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    17: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    18: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    19: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    20: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    21: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 10},
    22: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 10},
    23: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    24: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    25: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    26: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    27: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    28: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    29: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    30: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    31: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    32: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 9},
    33: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    34: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 10},
    35: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    36: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    37: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 9},
    38: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    39: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    40: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    41: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    42: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    43: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 10},
    44: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    45: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 5},
    46: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 9},
    47: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    48: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 10},
    49: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    50: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    51: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    52: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    53: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    54: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    55: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    56: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    57: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    58: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    59: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    60: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    61: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    62: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    63: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    64: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    65: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    66: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    67: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    68: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    69: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    70: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    71: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    72: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    73: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 7},
    74: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    75: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    76: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    77: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    78: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    79: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 10},
    80: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    81: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    82: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    83: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    84: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    85: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    86: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    87: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    88: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    89: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    90: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 8},
    91: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    92: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    93: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 8},
    94: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    95: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    96: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    97: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    98: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    99: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    100: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    101: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    102: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    103: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    104: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    105: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 10},
    106: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    107: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    108: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    109: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    110: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    111: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    112: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    113: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    114: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    115: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    116: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    117: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    118: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    119: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    120: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    121: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    122: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    123: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    124: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    125: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    126: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    127: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    128: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    129: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    130: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    131: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    132: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    133: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    134: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    135: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    136: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    137: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    138: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    139: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    140: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    141: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    142: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    143: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 4},
    144: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    145: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    146: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    147: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    148: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    149: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    150: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    151: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    152: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    153: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    154: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    155: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    156: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    157: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    158: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    159: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    160: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    161: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    162: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    163: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    164: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    165: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    166: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    167: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    168: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 4},
    169: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    170: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    171: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    172: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    173: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    174: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    175: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    176: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    177: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    178: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    179: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    180: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    181: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    182: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    183: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    184: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    185: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    186: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    187: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    188: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    189: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    190: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    191: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    192: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    193: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    194: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    195: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    196: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    197: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    198: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    199: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    200: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    201: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    202: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    203: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    204: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    205: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    206: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    207: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    208: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    209: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    210: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    211: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    212: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    213: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    214: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    215: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    216: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    217: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    218: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    219: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    220: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    221: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    222: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    223: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    224: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    225: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    226: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    227: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    228: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    229: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    230: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    231: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    232: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    233: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    234: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    235: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    236: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    237: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    238: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    239: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    240: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    241: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    242: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    243: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    244: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    245: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    246: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    247: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    248: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    249: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    250: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    251: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    252: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    253: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    254: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    255: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    256: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    257: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    258: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    259: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    260: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    261: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    262: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    263: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    264: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    265: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    266: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    267: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    268: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    269: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    270: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses'
: 8},
    271: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    272: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    273: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    274: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    275: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 8},
    276: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    277: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    278: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    279: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    280: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    281: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    282: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    283: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    284: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    285: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    286: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    287: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    288: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    289: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    290: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    291: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    292: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    293: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    294: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    295: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    296: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    297: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    298: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    299: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 4},
    300: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    301: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    302: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    303: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    304: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    305: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    306: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    307: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    308: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    309: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    310: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    311: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    312: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    313: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    314: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    315: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 4},
    316: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    317: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    318: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    319: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    320: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    321: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    322: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    323: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    324: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    325: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    326: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    327: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    328: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    329: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    330: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    331: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    332: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    333: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    334: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    335: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    336: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    337: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    338: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    339: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    340: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    341: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    342: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    343: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    344: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses'
: 8},
    345: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    346: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    347: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    348: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    349: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    350: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    351: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    352: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    353: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    354: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    355: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    356: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    357: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    358: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    359: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    360: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    361: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    362: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    363: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    364: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    365: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    366: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    367: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    368: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    369: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    370: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    371: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    372: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    373: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    374: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    375: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    376: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    377: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    378: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    379: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    380: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 9},
    381: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    382: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    383: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    384: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    385: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    386: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    387: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    388: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 5},
    389: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    390: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 6},
    391: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    392: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    393: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    394: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    395: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    396: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    397: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    398: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    399: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 7},
    400: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    401: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    402: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    403: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    404: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    405: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    406: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses'
: 8},
    407: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    408: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    409: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    410: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    411: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    412: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    413: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    414: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    415: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    416: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    417: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    418: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    419: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    420: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    421: {'Ketersediaan_Toilet': 'no', 'Ketersediaan_Lahan_Parkir': 'no', 'Kemudahan_Akses': 9},
    422: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    423: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    424: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    425: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    426: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    427: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    428: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    429: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    430: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 8},
    431: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    432: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    433: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    434: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    435: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9},
    436: {'Ketersediaan_Toilet': 'yes', 'Ketersediaan_Lahan_Parkir': 'yes', 'Kemudahan_Akses': 9}
}

df['Ketersediaan_Toilet'] = 'no'
df['Ketersediaan_Lahan_Parkir'] = 'no'
df['Kemudahan_Akses'] = np.nan

for index, values in full_data_update.items():
    df.loc[index, 'Ketersediaan_Toilet'] = values['Ketersediaan_Toilet']
    df.loc[index, 'Ketersediaan_Lahan_Parkir'] = values['Ketersediaan_Lahan_Parkir']
    df.loc[index, 'Kemudahan_Akses'] = values['Kemudahan_Akses']

mean_time = df['Time_Minutes'].mean()
df['Time_Minutes'].fillna(mean_time, inplace=True)

print("--- Data Awal (5 Baris Pertama) ---")
print(df.head())
print("\n" + "="*50 + "\n")
print("--- Data Akhir (5 Baris Terakhir) ---")
print(df.tail())
print("\n" + "="*50 + "\n")
print("--- Info DataFrame ---")
df.info()

df.to_csv('tourism_data_updated.csv', index=False)
print("\nData telah disimpan ke 'tourism_data_updated.csv'")
# Out:
# File 'tourism_with_id_without_description_and_coordinate.csv' berhasil dimuat.
# --- Data Awal (5 Baris Pertama) ---
#    Place_Id                         Place_Name       Category     City  \
# 0         1                   Monumen Nasional         Budaya  Jakarta
# 1         2                           Kota Tua         Budaya  Jakarta
# 2         3                      Dunia Fantasi  Taman Hiburan  Jakarta
# 3         4  Taman Mini Indonesia Indah (TMII)  Taman Hiburan  Jakarta
# 4         5           Atlantis Water Adventure  Taman Hiburan  Jakarta
#
#     Price  Rating  Time_Minutes Ketersediaan_Toilet Ketersediaan_Lahan_Parkir  \
# 0   20000     4.6     15.000000                 yes                       yes
# 1       0     4.6     90.000000                 yes                       yes
# 2  270000     4.6    360.000000                 yes                       yes
# 3   10000     4.5     82.609756                 yes                       yes
# ...
